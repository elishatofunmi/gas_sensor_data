# %%
import os
import sys
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'B1_GCO_F070_R1.txt',
#  'B1_GCO_F070_R2.txt',
#  'B1_GCO_F070_R3.txt',
#  'B1_GCO_F070_R4.txt',
#  'Box_plot_of_sense_eightboard_one_CO_at_70ppm.jpeg',
#  'Box_plot_of_sense_eight_no_outliers_board_one_CO_at_70ppm.jpeg',
#  'Box_plot_of_sense_fiveboard_one_CO_at_70ppm.jpeg',
#  'Box_plot_of_sense_five_no_outliers_board_one_CO_at_70ppm.jpeg',
#  'Box_plot_of_sense_fourboard_one_CO_at_70ppm.jpeg',
#  'Box_plot_of_sense_four_no_outliers_board_one_CO_at_70ppm.jpeg',
#  'Box_plot_of_sense_oneboard_one_CO_at_70ppm.jpeg',
#  'Box_plot_of_sense_one_no_outliers_board_one_CO_at_70ppm.jpeg',
#  'Box_plot_of_sense_sevenboard_one_CO_at_70ppm.jpeg',
#  'Box_plot_of_sense_seven_no_outliers_board_one_CO_at_70ppm.jpeg',
#  'Box_plot_of_sense_sixboard_one_CO_at_70ppm.jpeg',
#  'Box_plot_of_sense_six_no_outliers_board_one_CO_at_70ppm.jpeg',
#  'Box_plot_of_sense_threeboard_one_CO_at_70ppm.jpeg',
#  'Box_plot_of_sense_three_no_outliers_board_one_CO_at_70ppm.jpeg',
# ...

# %%
import pandas as pd
repitition_one = pd.read_csv(r'B1_GCO_F070_R1.txt',sep = '\t',header = None)
repitition_one.columns = ['time','sense_one', 'sense_two', 'sense_three','sense_four','sense_five',
                          'sense_six','sense_seven','sense_eight']
repitition_one.head()
# Out:
#    time  sense_one  sense_two  sense_three  sense_four  sense_five  sense_six  \
# 0  0.00      38.99      18.56        21.60        5.55       72.85      45.57
# 1  0.01      38.99      18.61        21.63        5.55       72.85      45.67
# 2  0.02      38.99      18.53        21.60        5.55       72.63      45.57
# 3  0.03      38.91      18.56        21.60        5.55       72.63      45.67
# 4  0.04      38.99      18.56        21.60        5.55       72.85      45.57
#
#    sense_seven  sense_eight
# 0        55.54         7.01
# 1        55.54         7.03
# 2        55.54         7.01
# 3        55.54         7.01
# 4        55.54         7.01

# %%
repitition_two = pd.read_csv(r'B1_GCO_F070_R2.txt',sep = '\t',header = None)
repitition_two.columns = ['time','sense_one', 'sense_two', 'sense_three','sense_four','sense_five',
                          'sense_six','sense_seven','sense_eight']
repitition_two.head()
# Out:
#    time  sense_one  sense_two  sense_three  sense_four  sense_five  sense_six  \
# 0  0.00      37.35      17.47        20.33        5.86       70.28      42.57
# 1  0.01      37.35      17.50        20.33        5.87       70.08      42.66
# 2  0.02      37.35      17.50        20.33        5.87       70.28      42.57
# 3  0.03      37.35      17.47        20.33        5.86       70.28      42.75
# 4  0.04      37.35      17.50        20.33        5.87       70.28      42.66
#
#    sense_seven  sense_eight
# 0        53.92         7.03
# 1        53.92         7.01
# 2        53.92         7.03
# 3        53.79         7.03
# 4        53.92         7.03

# %%
repitition_three = pd.read_csv(r'B1_GCO_F070_R3.txt',sep = '\t',header = None)
repitition_three.columns = ['time','sense_one', 'sense_two', 'sense_three','sense_four','sense_five',
                          'sense_six','sense_seven','sense_eight']
repitition_three.head()
# Out:
#    time  sense_one  sense_two  sense_three  sense_four  sense_five  sense_six  \
# 0  0.00       44.3      21.93        24.78        8.18       81.11      49.73
# 1  0.01       44.3      21.93        24.82        8.18       81.11      49.73
# 2  0.02       44.3      21.96        24.78        8.19       81.11      49.73
# 3  0.03       44.3      21.93        24.82        8.19       81.11      49.73
# 4  0.04       44.4      21.96        24.82        8.18       81.11      49.85
#
#    sense_seven  sense_eight
# 0        65.56         8.76
# 1        65.56         8.75
# 2        65.56         8.79
# 3        65.56         8.76
# 4        65.56         8.77

# %%
repitition_four = pd.read_csv(r'B1_GCO_F070_R4.txt',sep = '\t',header = None)
repitition_four.columns = ['time','sense_one', 'sense_two', 'sense_three','sense_four','sense_five',
                          'sense_six','sense_seven','sense_eight']
repitition_four.head()
# Out:
#    time  sense_one  sense_two  sense_three  sense_four  sense_five  sense_six  \
# 0  0.00       47.1      23.16        26.45        7.91       86.79      50.90
# 1  0.01       47.2      23.16        26.45        7.90       86.79      51.02
# 2  0.02       47.1      23.16        26.41        7.89       86.79      50.78
# 3  0.03       47.1      23.16        26.41        7.90       86.79      50.90
# 4  0.04       47.1      23.19        26.41        7.90       86.79      50.90
#
#    sense_seven  sense_eight
# 0        69.82         8.10
# 1        69.82         8.10
# 2        69.82         8.09
# 3        69.82         8.10
# 4        69.62         8.09

# %%
import matplotlib.pyplot as plt

for key in repitition_one.keys():
    plt.boxplot(repitition_one[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ 'board_one_CO_at_70ppm.jpeg')

# %%
repitition_one['sense_one'][repitition_one['sense_one'] < 38.2] = 38.2
repitition_one['sense_one'][repitition_one['sense_one'] > 39.5] = 39.5

# %%
repitition_one['sense_two'][repitition_one['sense_two'] < 18.24] = 18.24
repitition_one['sense_two'][repitition_one['sense_two'] > 18.8] = 18.8

# %%
repitition_one['sense_three'][repitition_one['sense_three'] < 21.2] = 21.2
repitition_one['sense_three'][repitition_one['sense_three'] > 21.7] = 21.7

# %%
repitition_one['sense_four'][repitition_one['sense_four'] < 4.9 ]= 4.9

# %%
repitition_one['sense_five'][repitition_one['sense_five'] < 71.2] = 71.2
repitition_one['sense_five'][repitition_one['sense_five'] > 73] = 73

# %%
repitition_one['sense_six'][repitition_one['sense_six'] < 44.9] = 44.9
repitition_one['sense_six'][repitition_one['sense_six'] > 46.1] = 46.1

# %%
repitition_one['sense_seven'][repitition_one['sense_seven'] < 54.2]= 54.2
repitition_one['sense_seven'][repitition_one['sense_seven'] > 56] = 56

# %%
repitition_one['sense_eight'][repitition_one['sense_eight'] <5.1] = 5.1

# %%
import matplotlib.pyplot as plt

for key in repitition_one.keys():
    plt.boxplot(repitition_one[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ '_no_outliers_board_one_CO_at_70ppm.jpeg')

# %%
import matplotlib.pyplot as plt

for key in repitition_two.keys():
    plt.boxplot(repitition_two[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ 'board_onerepiition2_CO_at_70ppm.jpeg')

# %%
def complete_2():
    repitition_two['sense_one'][repitition_two['sense_one'] < 36.7] = 36.7
    repitition_two['sense_one'][repitition_two['sense_one'] > 37.7] = 37.7
    
    repitition_two['sense_two'][repitition_two['sense_two'] < 17.19] = 17.19
    repitition_two['sense_two'][repitition_two['sense_two'] > 17.7] = 17.7
    
    repitition_two['sense_three'][repitition_two['sense_three'] < 20] = 20
    repitition_two['sense_three'][repitition_two['sense_three'] > 20.5] = 20.5
    
    repitition_two['sense_four'][repitition_two['sense_four'] < 4.9 ]= 4.9
    
    repitition_two['sense_five'][repitition_two['sense_five'] < 69.1] = 69.1
    repitition_two['sense_five'][repitition_two['sense_five'] > 70.5] = 70.5
    
    repitition_two['sense_six'][repitition_two['sense_six'] < 41.9] = 41.9
    repitition_two['sense_six'][repitition_two['sense_six'] > 43.5] = 43.5
    
    repitition_two['sense_seven'][repitition_two['sense_seven'] < 52.5]= 52.5
    repitition_two['sense_seven'][repitition_two['sense_seven'] > 54.5]= 54.5
    
    repitition_two['sense_eight'][repitition_two['sense_eight'] <4.9] = 4.9
    
    return

complete_2()

# %%
import matplotlib.pyplot as plt

for key in repitition_two.keys():
    plt.boxplot(repitition_two[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ '_no_outliers_repitition2_board_one_CO_at_70ppm.jpeg')

# %%
import matplotlib.pyplot as plt

for key in repitition_three.keys():
    plt.boxplot(repitition_three[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ 'board_onerepiition3_CO_at_70ppm.jpeg')

# %%
def complete_3():
    repitition_three['sense_one'][repitition_three['sense_one'] < 43.95] = 43.95
    
    repitition_three['sense_two'][repitition_three['sense_two'] < 21.8] = 21.8
    
    repitition_three['sense_three'][repitition_three['sense_three'] < 24.45] = 24.45
    
    repitition_three['sense_four'][repitition_three['sense_four'] < 7.6 ]= 7.6
    
    repitition_three['sense_five'][repitition_three['sense_five'] < 80.1] = 80.1
    repitition_three['sense_five'][repitition_three['sense_five'] > 81.9] = 81.9
    
    repitition_three['sense_six'][repitition_three['sense_six'] < 49] = 49
    
    repitition_three['sense_seven'][repitition_three['sense_seven'] < 64.1]= 64.1
    
    repitition_three['sense_eight'][repitition_three['sense_eight'] <7.4] = 7.4
    
    return

complete_3()

# %%
import matplotlib.pyplot as plt

for key in repitition_three.keys():
    plt.boxplot(repitition_three[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ 'board_one_no_outliers_repiition4_CO_at_70ppm.jpeg')

# %%
import matplotlib.pyplot as plt

for key in repitition_four.keys():
    plt.boxplot(repitition_four[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ 'board_onerepiition4_CO_at_70ppm.jpeg')

# %%
def complete_4():
    repitition_four['sense_one'][repitition_four['sense_one'] < 46.2] = 46.2
    repitition_four['sense_one'][repitition_four['sense_one'] > 47.3] = 47.3
    
    repitition_four['sense_two'][repitition_four['sense_two'] < 22.85] = 22.85
    
    repitition_four['sense_three'][repitition_four['sense_three'] < 25.80] = 25.80
    
    repitition_four['sense_four'][repitition_four['sense_four'] < 6.3]= 6.3
    
    repitition_four['sense_five'][repitition_four['sense_five'] < 85] = 85
    repitition_four['sense_five'][repitition_four['sense_five'] > 87] = 87
    
    repitition_four['sense_six'][repitition_four['sense_six'] < 50.3] = 50.3
    
    repitition_four['sense_seven'][repitition_four['sense_seven'] < 67.9]= 67.9
    
    repitition_four['sense_eight'][repitition_four['sense_eight'] <5.8] = 5.8
    
    return

complete_4()

# %%
import matplotlib.pyplot as plt

for key in repitition_four.keys():
    plt.boxplot(repitition_four[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ 'board_one_no_outliers_repiition4_CO_at_70ppm.jpeg')

# %%
final_repitition = (repitition_one + repitition_two+repitition_three + repitition_four) / 4

# %%
final_repitition.head()
# Out:
#    time  sense_one  sense_two  sense_three  sense_four  sense_five  sense_six  \
# 0  0.00     41.935    20.2800      23.2900       6.875     77.7575    47.1925
# 1  0.01     41.960    20.3000      23.3075       6.875     77.7075    47.2700
# 2  0.02     41.935    20.2875      23.2800       6.875     77.7025    47.1625
# 3  0.03     41.915    20.2800      23.2900       6.875     77.7025    47.2625
# 4  0.04     41.960    20.3025      23.2900       6.875     77.7575    47.2450
#
#    sense_seven  sense_eight
# 0      61.2100       7.7250
# 1      61.2100       7.7225
# 2      61.2100       7.7300
# 3      61.1775       7.7250
# 4      61.1600       7.7250

# %%
final_repitition.to_csv('Repitition_CO_at_70_ppm.csv')
