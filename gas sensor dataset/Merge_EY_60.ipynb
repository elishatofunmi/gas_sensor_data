# %%
import pandas as pd
repitition_one = pd.read_csv(r'B1_GEy_F060_R1.txt',sep = '\t',header = None)
repitition_one.columns = ['time','sense_one', 'sense_two', 'sense_three','sense_four','sense_five',
                          'sense_six','sense_seven','sense_eight']
repitition_two = pd.read_csv(r'B1_GEy_F060_R2.txt',sep = '\t',header = None)
repitition_two.columns = ['time','sense_one', 'sense_two', 'sense_three','sense_four','sense_five',
                          'sense_six','sense_seven','sense_eight']
repitition_three = pd.read_csv(r'B1_GEy_F060_R3.txt',sep = '\t',header = None)
repitition_three.columns = ['time','sense_one', 'sense_two', 'sense_three','sense_four','sense_five',
                          'sense_six','sense_seven','sense_eight']
repitition_four = pd.read_csv(r'B1_GEy_F060_R4.txt',sep = '\t',header = None)
repitition_four.columns = ['time','sense_one', 'sense_two', 'sense_three','sense_four','sense_five',
                          'sense_six','sense_seven','sense_eight']
repitition_four.head()
# Out:
#    time  sense_one  sense_two  sense_three  sense_four  sense_five  sense_six  \
# 0  0.00      40.26      20.14        22.70        8.02       74.20      44.41
# 1  0.01      40.26      20.16        22.70        8.02       73.97      44.41
# 2  0.02      40.34      20.14        22.70        8.01       73.97      44.50
# 3  0.03      40.26      20.16        22.70        8.01       73.97      44.31
# 4  0.04      40.26      20.16        22.73        8.00       73.97      44.41
#
#    sense_seven  sense_eight
# 0        60.27         8.15
# 1        60.27         8.15
# 2        59.95         8.15
# 3        60.27         8.15
# 4        60.27         8.16

# %%
import matplotlib.pyplot as plt

for key in repitition_one.keys():
    plt.boxplot(repitition_one[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ 'board_one_Ey_at_60ppm.jpeg')

# %%
def complete():
    repitition_one['sense_one'][repitition_one['sense_one'] < 42] = 42
    
    repitition_one['sense_two'][repitition_one['sense_two'] < 20] = 20
    repitition_one['sense_two'][repitition_one['sense_two'] > 20.9] = 20.9
    
    repitition_one['sense_three'][repitition_one['sense_three'] < 23.2] = 23.2
    
    repitition_one['sense_four'][repitition_one['sense_four'] < 4.0]= 4.0
    
    repitition_one['sense_five'][repitition_one['sense_five'] < 77] = 77
    
    repitition_one['sense_six'][repitition_one['sense_six'] < 48.2] = 48.2
    
    repitition_one['sense_seven'][repitition_one['sense_seven'] < 58]= 58
    
    repitition_one['sense_eight'][repitition_one['sense_eight'] < 3.8]= 3.8
        
    return

complete()

# %%
import matplotlib.pyplot as plt

for key in repitition_one.keys():
    plt.boxplot(repitition_one[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ '_no_outliers_board_one_Ey_at_60ppm.jpeg')

# %%
import matplotlib.pyplot as plt

for key in repitition_two.keys():
    plt.boxplot(repitition_two[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ 'board_onerepiition2_EA_at_60ppm.jpeg')

# %%
def complete_2():
    repitition_two['sense_one'][repitition_two['sense_one'] < 33.8] = 33.8
        
    repitition_two['sense_two'][repitition_two['sense_two'] < 15.9] = 15.9
    
    repitition_two['sense_three'][repitition_two['sense_three'] < 18.4] = 18.4
    
    repitition_two['sense_four'][repitition_two['sense_four'] < 5.0] = 5.0
        
    repitition_two['sense_five'][repitition_two['sense_five'] < 64] = 64
    
    repitition_two['sense_six'][repitition_two['sense_six'] < 39] = 39
    
    repitition_two['sense_seven'][repitition_two['sense_seven'] < 48]= 48  
    
    repitition_two['sense_eight'][repitition_two['sense_eight'] < 5.5]= 5.5
    return

complete_2()

# %%
import matplotlib.pyplot as plt

for key in repitition_two.keys():
    plt.boxplot(repitition_two[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ '_no_outliers_repitition2_board_one_Ey_at_60ppm.jpeg')

# %%
import matplotlib.pyplot as plt

for key in repitition_three.keys():
    plt.boxplot(repitition_three[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ 'board_onerepition3_Ey_at_60ppm.jpeg')

# %%
def complete_3():
    repitition_three['sense_one'][repitition_three['sense_one'] < 41.9] = 41.9
    
    repitition_three['sense_two'][repitition_three['sense_two'] < 20.5] = 20.5
    
    repitition_three['sense_three'][repitition_three['sense_three'] < 23] = 23
    
    repitition_three['sense_four'][repitition_three['sense_four'] < 4.8] = 4.8
        
    repitition_three['sense_five'][repitition_three['sense_five'] < 74] = 74
    
    repitition_three['sense_six'][repitition_three['sense_six'] < 44.5] = 44.5
        
    repitition_three['sense_seven'][repitition_three['sense_seven'] < 59]= 59
    
    repitition_three['sense_eight'][repitition_three['sense_eight'] < 4.1] = 4.1
    return

complete_3()

# %%
import matplotlib.pyplot as plt

for key in repitition_three.keys():
    plt.boxplot(repitition_three[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ 'board_one_no_outliers_repiition3_Ey_at_60ppm.jpeg')

# %%
import matplotlib.pyplot as plt

for key in repitition_four.keys():
    plt.boxplot(repitition_four[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ 'board_onerepiition4_Ey_at_60ppm.jpeg')

# %%
def complete_4():
    repitition_four['sense_one'][repitition_four['sense_one'] < 38.9] = 38.9
        
    repitition_four['sense_two'][repitition_four['sense_two'] < 19.8] = 19.8
    
    repitition_four['sense_three'][repitition_four['sense_three'] < 21.7] = 21.7

    repitition_four['sense_four'][repitition_four['sense_four'] < 5.2] = 5.2

    repitition_four['sense_five'][repitition_four['sense_five'] < 70] = 70
    
    repitition_four['sense_six'][repitition_four['sense_six'] < 42.2] = 42.2
        
    repitition_four['sense_seven'][repitition_four['sense_seven'] < 55.2]= 55.2
    
    repitition_four['sense_eight'][repitition_four['sense_eight'] < 4.6]= 4.6
    return

complete_4()

# %%
import matplotlib.pyplot as plt

for key in repitition_four.keys():
    plt.boxplot(repitition_four[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ 'board_one_no_outliers_repiition4_Ey_at_60ppm.jpeg')

# %%
final_repitition = (repitition_one + repitition_two+repitition_three + repitition_four) / 4

# %%
final_repitition.to_csv('Repitition_Ey_at_60_ppm.csv')
