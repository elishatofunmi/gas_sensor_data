# %%
import pandas as pd
repitition_one = pd.read_csv(r'B1_GEy_F050_R1.txt',sep = '\t',header = None)
repitition_one.columns = ['time','sense_one', 'sense_two', 'sense_three','sense_four','sense_five',
                          'sense_six','sense_seven','sense_eight']
repitition_two = pd.read_csv(r'B1_GEy_F050_R2.txt',sep = '\t',header = None)
repitition_two.columns = ['time','sense_one', 'sense_two', 'sense_three','sense_four','sense_five',
                          'sense_six','sense_seven','sense_eight']
repitition_three = pd.read_csv(r'B1_GEy_F050_R3.txt',sep = '\t',header = None)
repitition_three.columns = ['time','sense_one', 'sense_two', 'sense_three','sense_four','sense_five',
                          'sense_six','sense_seven','sense_eight']
repitition_four = pd.read_csv(r'B1_GEy_F050_R4.txt',sep = '\t',header = None)
repitition_four.columns = ['time','sense_one', 'sense_two', 'sense_three','sense_four','sense_five',
                          'sense_six','sense_seven','sense_eight']
repitition_four.head()
# Out:
#    time  sense_one  sense_two  sense_three  sense_four  sense_five  sense_six  \
# 0  0.00      40.18      20.16        22.59        8.04       73.52       44.5
# 1  0.01      40.10      20.16        22.63        8.04       73.52       44.5
# 2  0.02      40.10      20.16        22.63        8.04       73.52       44.5
# 3  0.03      40.10      20.16        22.59        8.04       73.52       44.5
# 4  0.04      40.10      20.16        22.59        8.04       73.52       44.5
#
#    sense_seven  sense_eight
# 0        59.95         8.23
# 1        59.95         8.22
# 2        59.80         8.23
# 3        59.95         8.23
# 4        59.80         8.24

# %%
import matplotlib.pyplot as plt

for key in repitition_one.keys():
    plt.boxplot(repitition_one[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ 'board_one_Ey_at_50ppm.jpeg')

# %%
def complete():
    repitition_one['sense_one'][repitition_one['sense_one'] < 44] = 44
    repitition_one['sense_one'][repitition_one['sense_one'] > 44.8] = 44.8
    
    repitition_one['sense_two'][repitition_one['sense_two'] < 20.7] = 20.7
    repitition_one['sense_two'][repitition_one['sense_two'] > 21.12]= 21.12
    
    repitition_one['sense_three'][repitition_one['sense_three'] < 24.2] = 24.2
    repitition_one['sense_three'][repitition_one['sense_three'] > 24.8] = 24.8
    
    repitition_one['sense_four'][repitition_one['sense_four'] < 4.1]= 4.1
    
    repitition_one['sense_five'][repitition_one['sense_five'] < 79] = 79
    
    repitition_one['sense_six'][repitition_one['sense_six'] < 49.2] = 49.2
    
    repitition_one['sense_seven'][repitition_one['sense_seven'] < 59]= 59
    
    repitition_one['sense_eight'][repitition_one['sense_eight'] < 3.8]= 3.8
        
    return

complete()

# %%
import matplotlib.pyplot as plt

for key in repitition_one.keys():
    plt.boxplot(repitition_one[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ '_no_outliers_board_one_Ey_at_50ppm.jpeg')

# %%
import matplotlib.pyplot as plt

for key in repitition_two.keys():
    plt.boxplot(repitition_two[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ 'board_onerepiition2_Ey_at_50ppm.jpeg')

# %%
def complete_2():
    repitition_two['sense_one'][repitition_two['sense_one'] < 34] = 34
    repitition_two['sense_one'][repitition_two['sense_one'] > 35.8] = 35.8
        
    repitition_two['sense_two'][repitition_two['sense_two'] < 16.20] = 16.20
    
    repitition_two['sense_three'][repitition_two['sense_three'] < 18.6] = 18.6
    repitition_two['sense_three'][repitition_two['sense_three'] > 19.4] = 19.4
    
    repitition_two['sense_four'][repitition_two['sense_four'] < 4.2] = 4.2
        
    repitition_two['sense_five'][repitition_two['sense_five'] < 64] = 64
    repitition_two['sense_five'][repitition_two['sense_five'] > 67.5] = 67.5
    
    repitition_two['sense_six'][repitition_two['sense_six'] < 39.8] = 39.8
    
    repitition_two['sense_seven'][repitition_two['sense_seven'] < 49]= 49  
    
    repitition_two['sense_eight'][repitition_two['sense_eight'] < 4.0]= 4.0
    return

complete_2()

# %%
import matplotlib.pyplot as plt

for key in repitition_two.keys():
    plt.boxplot(repitition_two[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ '_no_outliers_repitition2_board_one_Ey_at_50ppm.jpeg')

# %%
import matplotlib.pyplot as plt

for key in repitition_three.keys():
    plt.boxplot(repitition_three[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ 'board_onerepition3_Ey_at_50ppm.jpeg')

# %%
def complete_3():
    repitition_three['sense_one'][repitition_three['sense_one'] < 42.2] = 42.2
    repitition_three['sense_one'][repitition_three['sense_one'] > 43.5] = 43.5
    
    repitition_three['sense_two'][repitition_three['sense_two'] < 20.82] = 20.82
    
    repitition_three['sense_three'][repitition_three['sense_three'] < 23.24] = 23.24
    
    repitition_three['sense_four'][repitition_three['sense_four'] < 5.1] = 5.1
        
    repitition_three['sense_five'][repitition_three['sense_five'] < 75.2] = 75.2
    
    repitition_three['sense_six'][repitition_three['sense_six'] < 46.3] = 46.3
        
    repitition_three['sense_seven'][repitition_three['sense_seven'] < 60.3]= 60.3
    
    repitition_three['sense_eight'][repitition_three['sense_eight'] < 4.3] = 4.3
    return

complete_3()

# %%
import matplotlib.pyplot as plt

for key in repitition_three.keys():
    plt.boxplot(repitition_three[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ 'board_one_no_outliers_repiition3_Ey_at_50ppm.jpeg')

# %%
import matplotlib.pyplot as plt

for key in repitition_four.keys():
    plt.boxplot(repitition_four[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ 'board_onerepiition4_Ey_at_50ppm.jpeg')

# %%
def complete_4():
    repitition_four['sense_one'][repitition_four['sense_one'] < 39.2] = 39.2
    repitition_four['sense_one'][repitition_four['sense_one'] > 40.3] = 40.3
        
    repitition_four['sense_two'][repitition_four['sense_two'] < 19.8] = 19.8
    
    repitition_four['sense_three'][repitition_four['sense_three'] < 21.8] = 21.8

    repitition_four['sense_four'][repitition_four['sense_four'] < 5.2] = 5.2

    repitition_four['sense_five'][repitition_four['sense_five'] < 70] = 70
    
    repitition_four['sense_six'][repitition_four['sense_six'] < 42.5] = 42.5
        
    repitition_four['sense_seven'][repitition_four['sense_seven'] < 55.5]= 55.5
    
    repitition_four['sense_eight'][repitition_four['sense_eight'] < 4.8]= 4.8
    return

complete_4()

# %%
import matplotlib.pyplot as plt

for key in repitition_four.keys():
    plt.boxplot(repitition_four[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ 'board_one_no_outliers_repiition4_Ey_at_50ppm.jpeg')

# %%
final_repitition = (repitition_one + repitition_two+repitition_three + repitition_four) / 4

# %%
final_repitition.to_csv('Repitition_Ey_at_50_ppm.csv')
