# %%
import pandas as pd
repitition_one = pd.read_csv(r'B1_GEa_F020_R1.txt',sep = '\t',header = None)
repitition_one.columns = ['time','sense_one', 'sense_two', 'sense_three','sense_four','sense_five',
                          'sense_six','sense_seven','sense_eight']
repitition_two = pd.read_csv(r'B1_GEa_F020_R2.txt',sep = '\t',header = None)
repitition_two.columns = ['time','sense_one', 'sense_two', 'sense_three','sense_four','sense_five',
                          'sense_six','sense_seven','sense_eight']
repitition_three = pd.read_csv(r'B1_GEa_F020_R3.txt',sep = '\t',header = None)
repitition_three.columns = ['time','sense_one', 'sense_two', 'sense_three','sense_four','sense_five',
                          'sense_six','sense_seven','sense_eight']
repitition_four = pd.read_csv(r'B1_GEa_F020_R4.txt',sep = '\t',header = None)
repitition_four.columns = ['time','sense_one', 'sense_two', 'sense_three','sense_four','sense_five',
                          'sense_six','sense_seven','sense_eight']
repitition_four.head()
# Out:
#    time  sense_one  sense_two  sense_three  sense_four  sense_five  sense_six  \
# 0  0.00      49.96      24.48        27.92        7.56       91.54      53.00
# 1  0.01      49.85      24.44        27.92        7.56       91.54      52.87
# 2  0.02      49.96      24.44        27.92        7.54       91.54      52.87
# 3  0.03      49.96      24.44        27.97        7.55       91.54      53.00
# 4  0.04      49.96      24.40        27.92        7.55       91.54      53.00
#
#    sense_seven  sense_eight
# 0        72.79         7.57
# 1        72.79         7.57
# 2        72.79         7.56
# 3        72.79         7.57
# 4        72.79         7.58

# %%
import matplotlib.pyplot as plt

for key in repitition_one.keys():
    plt.boxplot(repitition_one[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ 'board_one_EA_at_20ppm.jpeg')

# %%
def complete():
    repitition_one['sense_one'][repitition_one['sense_one'] < 39] = 39
    repitition_one['sense_one'][repitition_one['sense_one'] > 40.5] = 40.5
    
    repitition_one['sense_two'][repitition_one['sense_two'] < 18.78] = 18.78
    
    repitition_one['sense_three'][repitition_one['sense_three'] < 21.6] = 21.6
    repitition_one['sense_three'][repitition_one['sense_three'] > 22.4] = 22.4
    
    repitition_one['sense_four'][repitition_one['sense_four'] < 2.0]= 2.0
    
    repitition_one['sense_five'][repitition_one['sense_five'] < 72.4] = 72.4
    
    repitition_one['sense_six'][repitition_one['sense_six'] < 45.9] = 45.9
    repitition_one['sense_six'][repitition_one['sense_six'] > 47] = 47
    
    repitition_one['sense_seven'][repitition_one['sense_seven'] < 54.2]= 54.2
        
    return

complete()

# %%
import matplotlib.pyplot as plt

for key in repitition_one.keys():
    plt.boxplot(repitition_one[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ '_no_outliers_board_one_EA_at_20ppm.jpeg')

# %%
import matplotlib.pyplot as plt

for key in repitition_two.keys():
    plt.boxplot(repitition_two[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ 'board_onerepiition2_EA_at_20ppm.jpeg')

# %%
def complete_2():
    repitition_two['sense_one'][repitition_two['sense_one'] < 37] = 37
    repitition_two['sense_one'][repitition_two['sense_one'] > 39.9] = 39.9
        
    repitition_two['sense_three'][repitition_two['sense_three'] < 20.1] = 20.1
    
    repitition_two['sense_four'][repitition_two['sense_four'] < 2]= 2
    
    repitition_two['sense_five'][repitition_two['sense_five'] < 70] = 70
    repitition_two['sense_five'][repitition_two['sense_five'] > 75] = 75
        
    repitition_two['sense_seven'][repitition_two['sense_seven'] < 53]= 53    
    return

complete_2()

# %%
import matplotlib.pyplot as plt

for key in repitition_two.keys():
    plt.boxplot(repitition_two[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ '_no_outliers_repitition2_board_one_EA_at_20ppm.jpeg')

# %%
import matplotlib.pyplot as plt

for key in repitition_three.keys():
    plt.boxplot(repitition_three[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ 'board_onerepition3_EA_at_20ppm.jpeg')

# %%
def complete_3():
    repitition_three['sense_one'][repitition_three['sense_one'] < 42.4] = 42.4
    repitition_three['sense_one'][repitition_three['sense_one'] > 44] = 44
    
    repitition_three['sense_three'][repitition_three['sense_three'] < 23.6] = 23.6
    
    repitition_three['sense_four'][repitition_three['sense_four'] < 2]= 2
    
    repitition_three['sense_five'][repitition_three['sense_five'] < 77] = 77
    repitition_three['sense_five'][repitition_three['sense_five'] > 81] = 81
        
    repitition_three['sense_seven'][repitition_three['sense_seven'] < 62]= 62    
    return

complete_3()

# %%
import matplotlib.pyplot as plt

for key in repitition_three.keys():
    plt.boxplot(repitition_three[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ 'board_one_no_outliers_repiition3_EA_at_20ppm.jpeg')

# %%
import matplotlib.pyplot as plt

for key in repitition_four.keys():
    plt.boxplot(repitition_four[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ 'board_onerepiition4_EA_at_20ppm.jpeg')

# %%
def complete_4():
    repitition_four['sense_one'][repitition_four['sense_one'] < 49.1] = 49.1
    repitition_four['sense_one'][repitition_four['sense_one'] > 50.2] = 50.2
    
    repitition_four['sense_three'][repitition_four['sense_three'] < 27.4] = 27.4
    
    repitition_four['sense_four'][repitition_four['sense_four'] < 4]= 4
    
    repitition_four['sense_five'][repitition_four['sense_five'] < 89.8] = 89.8
    repitition_four['sense_five'][repitition_four['sense_five'] > 92] = 92
    
    repitition_four['sense_six'][repitition_four['sense_six'] < 52.78] = 52.78
    repitition_four['sense_six'][repitition_four['sense_six'] > 53.5] = 53.5
    
    repitition_four['sense_seven'][repitition_four['sense_seven'] < 71]= 71
    
    repitition_four['sense_eight'][repitition_four['sense_eight'] <3.4] = 3.4
    
    return

complete_4()

# %%
import matplotlib.pyplot as plt

for key in repitition_four.keys():
    plt.boxplot(repitition_four[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ 'board_one_no_outliers_repiition4_EA_at_20ppm.jpeg')

# %%
final_repitition = (repitition_one + repitition_two+repitition_three + repitition_four) / 4

# %%
final_repitition.to_csv('Repitition_EA_at_20_ppm.csv')
