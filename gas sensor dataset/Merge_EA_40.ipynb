# %%
import pandas as pd
repitition_one = pd.read_csv(r'B1_GEa_F040_R1.txt',sep = '\t',header = None)
repitition_one.columns = ['time','sense_one', 'sense_two', 'sense_three','sense_four','sense_five',
                          'sense_six','sense_seven','sense_eight']
repitition_two = pd.read_csv(r'B1_GEa_F040_R2.txt',sep = '\t',header = None)
repitition_two.columns = ['time','sense_one', 'sense_two', 'sense_three','sense_four','sense_five',
                          'sense_six','sense_seven','sense_eight']
repitition_three = pd.read_csv(r'B1_GEa_F040_R3.txt',sep = '\t',header = None)
repitition_three.columns = ['time','sense_one', 'sense_two', 'sense_three','sense_four','sense_five',
                          'sense_six','sense_seven','sense_eight']
repitition_four = pd.read_csv(r'B1_GEa_F040_R4.txt',sep = '\t',header = None)
repitition_four.columns = ['time','sense_one', 'sense_two', 'sense_three','sense_four','sense_five',
                          'sense_six','sense_seven','sense_eight']
repitition_four.head()
# Out:
#    time  sense_one  sense_two  sense_three  sense_four  sense_five  sense_six  \
# 0  0.00      48.49      23.91        27.15        7.34       88.95      51.99
# 1  0.01      48.49      23.91        27.15        7.34       89.27      51.99
# 2  0.02      48.49      23.91        27.15        7.35       88.95      52.12
# 3  0.03      48.49      23.91        27.15        7.34       88.95      51.99
# 4  0.04      48.60      23.91        27.20        7.35       89.27      52.24
#
#    sense_seven  sense_eight
# 0        71.28         7.40
# 1        71.28         7.40
# 2        71.28         7.40
# 3        71.28         7.41
# 4        71.28         7.41

# %%
import matplotlib.pyplot as plt

for key in repitition_one.keys():
    plt.boxplot(repitition_one[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ 'board_one_EA_at_40ppm.jpeg')

# %%
def complete():
    repitition_one['sense_one'][repitition_one['sense_one'] < 39.9] = 39.9
    repitition_one['sense_one'][repitition_one['sense_one'] > 41.4] = 41.4
    
    repitition_one['sense_two'][repitition_one['sense_two'] < 19.2] = 19.2
    repitition_one['sense_two'][repitition_one['sense_two'] > 19.6] = 19.6
    
    repitition_one['sense_three'][repitition_one['sense_three'] < 21.8] = 21.8
    
    repitition_one['sense_four'][repitition_one['sense_four'] < 1.4]= 1.4
    
    repitition_one['sense_five'][repitition_one['sense_five'] < 74] = 74
    
    repitition_one['sense_six'][repitition_one['sense_six'] < 47.2] = 47.2
    repitition_one['sense_six'][repitition_one['sense_six'] > 47.8] = 47.8
    
    repitition_one['sense_seven'][repitition_one['sense_seven'] < 55]= 55
        
    return

complete()

# %%
import matplotlib.pyplot as plt

for key in repitition_one.keys():
    plt.boxplot(repitition_one[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ '_no_outliers_board_one_EA_at_40ppm.jpeg')

# %%
import matplotlib.pyplot as plt

for key in repitition_two.keys():
    plt.boxplot(repitition_two[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ 'board_onerepiition2_EA_at_40ppm.jpeg')

# %%
def complete_2():
    repitition_two['sense_one'][repitition_two['sense_one'] < 37.5] = 37.5
        
    repitition_two['sense_two'][repitition_two['sense_two'] < 17.85] = 17.85
    
    repitition_two['sense_three'][repitition_two['sense_three'] < 20.2] = 20.2
    
    repitition_two['sense_four'][repitition_two['sense_four'] < 1.2] = 1.2
        
    repitition_two['sense_five'][repitition_two['sense_five'] < 71] = 71
    
    repitition_two['sense_six'][repitition_two['sense_six'] < 43.6] = 43.6
    repitition_two['sense_six'][repitition_two['sense_six'] > 45.37] = 45.37
    
    repitition_two['sense_seven'][repitition_two['sense_seven'] < 53.2]= 53.2    
    return

complete_2()

# %%
import matplotlib.pyplot as plt

for key in repitition_two.keys():
    plt.boxplot(repitition_two[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ '_no_outliers_repitition2_board_one_EA_at_40ppm.jpeg')

# %%
import matplotlib.pyplot as plt

for key in repitition_three.keys():
    plt.boxplot(repitition_three[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ 'board_onerepition3_EA_at_40ppm.jpeg')

# %%
def complete_3():
    repitition_three['sense_one'][repitition_three['sense_one'] < 42.2] = 42.2
    repitition_three['sense_one'][repitition_three['sense_one'] > 43.5] = 43.5
    
    repitition_three['sense_two'][repitition_three['sense_two'] < 20.98] = 20.98
    repitition_three['sense_two'][repitition_three['sense_two'] > 21.32] = 21.32
    
    repitition_three['sense_three'][repitition_three['sense_three'] < 23.8] = 23.8
    repitition_three['sense_three'][repitition_three['sense_three'] > 24.2] = 24.2
        
    repitition_three['sense_five'][repitition_three['sense_five'] < 77.785] = 77.785
    repitition_three['sense_five'][repitition_three['sense_five'] > 78] = 78
    
    repitition_three['sense_six'][repitition_three['sense_six'] < 47] = 47
    repitition_three['sense_six'][repitition_three['sense_six'] > 47.78] = 47.78
        
    repitition_three['sense_seven'][repitition_three['sense_seven'] < 62.5]= 62.5    
    return

complete_3()

# %%
import matplotlib.pyplot as plt

for key in repitition_three.keys():
    plt.boxplot(repitition_three[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ 'board_one_no_outliers_repiition3_EA_at_40ppm.jpeg')

# %%
import matplotlib.pyplot as plt

for key in repitition_four.keys():
    plt.boxplot(repitition_four[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ 'board_onerepiition4_EA_at_40ppm.jpeg')

# %%
def complete_4():
    repitition_four['sense_one'][repitition_four['sense_one'] < 47.8] = 47.8
    repitition_four['sense_one'][repitition_four['sense_one'] > 48.7] = 48.7
        
    repitition_four['sense_three'][repitition_four['sense_three'] < 26.6] = 26.6

    repitition_four['sense_four'][repitition_four['sense_four'] < 3.4] = 3.4

    repitition_four['sense_five'][repitition_four['sense_five'] < 87] = 87
        
    repitition_four['sense_seven'][repitition_four['sense_seven'] < 68.5]= 68.5
    
    repitition_four['sense_eight'][repitition_four['sense_eight'] < 2.4]= 2.4
    return

complete_4()

# %%
import matplotlib.pyplot as plt

for key in repitition_four.keys():
    plt.boxplot(repitition_four[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ 'board_one_no_outliers_repiition4_EA_at_40ppm.jpeg')

# %%
final_repitition = (repitition_one + repitition_two+repitition_three + repitition_four) / 4

# %%
final_repitition.to_csv('Repitition_EA_at_40_ppm.csv')
