# %%
import pandas as pd
repitition_one = pd.read_csv(r'B1_GME_F070_R1.txt',sep = '\t',header = None)
repitition_one.columns = ['time','sense_one', 'sense_two', 'sense_three','sense_four','sense_five',
                          'sense_six','sense_seven','sense_eight']
repitition_two = pd.read_csv(r'B1_GME_F070_R2.txt',sep = '\t',header = None)
repitition_two.columns = ['time','sense_one', 'sense_two', 'sense_three','sense_four','sense_five',
                          'sense_six','sense_seven','sense_eight']
repitition_three = pd.read_csv(r'B1_GME_F070_R3.txt',sep = '\t',header = None)
repitition_three.columns = ['time','sense_one', 'sense_two', 'sense_three','sense_four','sense_five',
                          'sense_six','sense_seven','sense_eight']
repitition_four = pd.read_csv(r'B1_GME_F070_R4.txt',sep = '\t',header = None)
repitition_four.columns = ['time','sense_one', 'sense_two', 'sense_three','sense_four','sense_five',
                          'sense_six','sense_seven','sense_eight']
repitition_four.head()
# Out:
#    time  sense_one  sense_two  sense_three  sense_four  sense_five  sense_six  \
# 0  0.00      40.26      20.25        22.73        8.13       73.75      44.69
# 1  0.01      40.26      20.25        22.76        8.12       73.97      44.60
# 2  0.02      40.26      20.25        22.76        8.12       73.75      44.69
# 3  0.03      40.18      20.28        22.73        8.12       73.97      44.60
# 4  0.04      40.18      20.25        22.76        8.12       73.97      44.60
#
#    sense_seven  sense_eight
# 0        60.11         8.18
# 1        60.11         8.20
# 2        60.11         8.20
# 3        59.95         8.20
# 4        59.95         8.20

# %%
import matplotlib.pyplot as plt

for key in repitition_one.keys():
    plt.boxplot(repitition_one[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ 'board_one_ME_at_70ppm.jpeg')

# %%
def complete():
    repitition_one['sense_one'][repitition_one['sense_one'] < 35.4] = 35.4
    
    repitition_one['sense_two'][repitition_one['sense_two'] < 17.9] = 17.9
    
    repitition_one['sense_three'][repitition_one['sense_three'] < 19.9] = 19.9
    
    repitition_one['sense_four'][repitition_one['sense_four'] < 5.0]= 5.0
    
    repitition_one['sense_five'][repitition_one['sense_five'] < 57] = 57
    
    repitition_one['sense_six'][repitition_one['sense_six'] < 37] = 37
    
    repitition_one['sense_seven'][repitition_one['sense_seven'] < 43]= 43
    
    repitition_one['sense_eight'][repitition_one['sense_eight'] <5.99] = 5.99
    
    return

complete()

# %%
import matplotlib.pyplot as plt

for key in repitition_one.keys():
    plt.boxplot(repitition_one[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ '_no_outliers_board_one_ME_at_70ppm.jpeg')

# %%
import matplotlib.pyplot as plt

for key in repitition_two.keys():
    plt.boxplot(repitition_two[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ 'board_onerepiition2_ME_at_70ppm.jpeg')

# %%
def complete_2():
    repitition_two['sense_one'][repitition_two['sense_one'] < 34.5] = 34.5
    
    repitition_two['sense_two'][repitition_two['sense_two'] < 16.2] = 16.2
    
    repitition_two['sense_three'][repitition_two['sense_three'] < 18.4] = 18.4
    
    repitition_two['sense_four'][repitition_two['sense_four'] < 5.52 ]= 5.52
    
    repitition_two['sense_five'][repitition_two['sense_five'] < 56] = 56
    
    repitition_two['sense_six'][repitition_two['sense_six'] < 35] = 35
    
    repitition_two['sense_seven'][repitition_two['sense_seven'] < 42]= 42
    
    repitition_two['sense_eight'][repitition_two['sense_eight'] <6.45] = 6.45
    
    return

complete_2()

# %%
import matplotlib.pyplot as plt

for key in repitition_two.keys():
    plt.boxplot(repitition_two[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ '_no_outliers_repitition2_board_one_ME_at_70ppm.jpeg')

# %%
import matplotlib.pyplot as plt

for key in repitition_three.keys():
    plt.boxplot(repitition_three[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ 'board_onerepition3_ME_at_70ppm.jpeg')

# %%
def complete_3():
    repitition_three['sense_one'][repitition_three['sense_one'] < 38] = 38
    
    repitition_three['sense_two'][repitition_three['sense_two'] < 19.6] = 19.6
    
    repitition_three['sense_three'][repitition_three['sense_three'] < 21.2] = 21.2
    
    repitition_three['sense_four'][repitition_three['sense_four'] < 6.90 ]= 6.90
    
    repitition_three['sense_five'][repitition_three['sense_five'] < 59] = 59
    
    repitition_three['sense_six'][repitition_three['sense_six'] < 36] = 36
    
    repitition_three['sense_seven'][repitition_three['sense_seven'] < 45]= 45
    
    repitition_three['sense_eight'][repitition_three['sense_eight'] <7.1] = 7.1
    
    return

complete_3()

# %%
import matplotlib.pyplot as plt

for key in repitition_three.keys():
    plt.boxplot(repitition_three[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ 'board_one_no_outliers_repiition3_ME_at_70ppm.jpeg')

# %%
import matplotlib.pyplot as plt

for key in repitition_four.keys():
    plt.boxplot(repitition_four[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ 'board_onerepiition4_ME_at_60ppm.jpeg')

# %%
def complete_4():
    repitition_four['sense_one'][repitition_four['sense_one'] < 36] = 36
    
    repitition_four['sense_two'][repitition_four['sense_two'] < 19] = 19
    
    repitition_four['sense_three'][repitition_four['sense_three'] < 21] = 21
    
    repitition_four['sense_four'][repitition_four['sense_four'] < 7.75 ]= 7.75
    
    repitition_four['sense_five'][repitition_four['sense_five'] < 55] = 55
    
    repitition_four['sense_six'][repitition_four['sense_six'] < 35] = 35
    
    repitition_four['sense_seven'][repitition_four['sense_seven'] < 43]= 43
    
    repitition_four['sense_eight'][repitition_four['sense_eight'] <7.65] = 7.65
    
    return

complete_4()

# %%
import matplotlib.pyplot as plt

for key in repitition_four.keys():
    plt.boxplot(repitition_four[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ 'board_one_no_outliers_repiition4_ME_at_70ppm.jpeg')

# %%
final_repitition = (repitition_one + repitition_two+repitition_three + repitition_four) / 4

# %%
final_repitition.to_csv('Repitition_ME_at_70_ppm.csv')
