# %%
import os
import sys
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'B1_GCO_F080_R1.txt',
#  'B1_GCO_F080_R2.txt',
#  'B1_GCO_F080_R3.txt',
#  'B1_GCO_F080_R4.txt',
#  'Box_plot_of_sense_eightboard_onerepiition2_CO_at_80ppm.jpeg',
#  'Box_plot_of_sense_eightboard_one_CO_at_80ppm.jpeg',
#  'Box_plot_of_sense_eight_no_outliers_board_one_CO_at_80ppm.jpeg',
#  'Box_plot_of_sense_fiveboard_onerepiition2_CO_at_80ppm.jpeg',
#  'Box_plot_of_sense_fiveboard_one_CO_at_80ppm.jpeg',
#  'Box_plot_of_sense_five_no_outliers_board_one_CO_at_80ppm.jpeg',
#  'Box_plot_of_sense_fourboard_onerepiition2_CO_at_80ppm.jpeg',
#  'Box_plot_of_sense_fourboard_one_CO_at_80ppm.jpeg',
#  'Box_plot_of_sense_four_no_outliers_board_one_CO_at_80ppm.jpeg',
#  'Box_plot_of_sense_oneboard_onerepiition2_CO_at_80ppm.jpeg',
#  'Box_plot_of_sense_oneboard_one_CO_at_80ppm.jpeg',
#  'Box_plot_of_sense_one_no_outliers_board_one_CO_at_80ppm.jpeg',
#  'Box_plot_of_sense_sevenboard_onerepiition2_CO_at_80ppm.jpeg',
#  'Box_plot_of_sense_sevenboard_one_CO_at_80ppm.jpeg',
# ...

# %%
import pandas as pd
repitition_one = pd.read_csv(r'B1_GCO_F080_R1.txt',sep = '\t',header = None)
repitition_one.columns = ['time','sense_one', 'sense_two', 'sense_three','sense_four','sense_five',
                          'sense_six','sense_seven','sense_eight']
repitition_one.head()
# Out:
#    time  sense_one  sense_two  sense_three  sense_four  sense_five  sense_six  \
# 0  0.00      38.91      18.64        21.60        5.53       72.85      45.77
# 1  0.01      38.99      18.61        21.60        5.55       73.08      45.67
# 2  0.02      38.99      18.64        21.60        5.54       72.85      45.67
# 3  0.03      38.99      18.61        21.63        5.53       72.85      45.67
# 4  0.04      38.99      18.64        21.63        5.54       72.85      45.67
#
#    sense_seven  sense_eight
# 0        55.54         6.91
# 1        55.67         6.92
# 2        55.67         6.91
# 3        55.67         6.92
# 4        55.54         6.91

# %%
repitition_two = pd.read_csv(r'B1_GCO_F080_R2.txt',sep = '\t',header = None)
repitition_two.columns = ['time','sense_one', 'sense_two', 'sense_three','sense_four','sense_five',
                          'sense_six','sense_seven','sense_eight']
repitition_two.head()
# Out:
#    time  sense_one  sense_two  sense_three  sense_four  sense_five  sense_six  \
# 0  0.00      38.01      17.77        20.66        6.02       71.33      43.20
# 1  0.01      38.01      17.77        20.66        6.01       71.33      43.20
# 2  0.02      38.01      17.77        20.66        6.02       71.33      43.29
# 3  0.03      38.01      17.74        20.63        6.01       71.33      43.29
# 4  0.04      38.01      17.74        20.63        6.01       71.33      43.20
#
#    sense_seven  sense_eight
# 0        54.72         7.17
# 1        54.72         7.18
# 2        54.72         7.17
# 3        54.72         7.18
# 4        54.72         7.17

# %%
repitition_three = pd.read_csv(r'B1_GCO_F080_R3.txt',sep = '\t',header = None)
repitition_three.columns = ['time','sense_one', 'sense_two', 'sense_three','sense_four','sense_five',
                          'sense_six','sense_seven','sense_eight']
repitition_three.head()
# Out:
#    time  sense_one  sense_two  sense_three  sense_four  sense_five  sense_six  \
# 0  0.00      44.78      22.03        25.02        8.14       81.92      49.96
# 1  0.01      44.78      22.00        25.06        8.13       81.92      49.96
# 2  0.02      44.88      22.03        25.06        8.13       81.92      49.96
# 3  0.03      44.78      21.96        25.02        8.14       81.92      49.96
# 4  0.04      44.78      22.03        25.02        8.14       81.65      50.08
#
#    sense_seven  sense_eight
# 0        66.30         8.72
# 1        66.11         8.72
# 2        66.30         8.72
# 3        66.11         8.71
# 4        66.11         8.72

# %%
repitition_four = pd.read_csv(r'B1_GCO_F080_R4.txt',sep = '\t',header = None)
repitition_four.columns = ['time','sense_one', 'sense_two', 'sense_three','sense_four','sense_five',
                          'sense_six','sense_seven','sense_eight']
repitition_four.head()
# Out:
#    time  sense_one  sense_two  sense_three  sense_four  sense_five  sense_six  \
# 0  0.00      46.78      23.23        26.33        7.97       86.49      51.14
# 1  0.01      46.78      23.19        26.33        7.96       86.49      51.26
# 2  0.02      46.78      23.19        26.33        7.98       86.19      51.14
# 3  0.03      46.78      23.19        26.33        7.96       86.49      51.26
# 4  0.04      46.78      23.19        26.33        7.96       86.49      51.14
#
#    sense_seven  sense_eight
# 0        69.62         8.21
# 1        69.62         8.23
# 2        69.62         8.23
# 3        69.62         8.22
# 4        69.82         8.23

# %%
import matplotlib.pyplot as plt

for key in repitition_one.keys():
    plt.boxplot(repitition_one[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ 'board_one_CO_at_80ppm.jpeg')

# %%
repitition_one['sense_one'][repitition_one['sense_one'] < 38.5] = 38.5

# %%
repitition_one['sense_two'][repitition_one['sense_two'] < 18.4] = 18.4

# %%
repitition_one['sense_three'][repitition_one['sense_three'] < 21.4] = 21.4

# %%
repitition_one['sense_four'][repitition_one['sense_four'] < 4.7 ]= 4.7

# %%
repitition_one['sense_five'][repitition_one['sense_five'] < 71.6] = 71.6

# %%
repitition_one['sense_six'][repitition_one['sense_six'] < 45.1] = 45.1

# %%
repitition_one['sense_seven'][repitition_one['sense_seven'] < 54.2]= 54.2

# %%
repitition_one['sense_eight'][repitition_one['sense_eight'] <4.7] = 4.7

# %%
import matplotlib.pyplot as plt

for key in repitition_one.keys():
    plt.boxplot(repitition_one[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ '_no_outliers_board_one_CO_at_80ppm.jpeg')

# %%
import matplotlib.pyplot as plt

for key in repitition_two.keys():
    plt.boxplot(repitition_two[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ 'board_onerepiition2_CO_at_80ppm.jpeg')

# %%
def complete_2():
    repitition_two['sense_one'][repitition_two['sense_one'] < 36.8] = 36.8
    
    repitition_two['sense_two'][repitition_two['sense_two'] < 17.3] = 17.3
    
    repitition_two['sense_three'][repitition_two['sense_three'] < 19.9] = 19.9
    
    repitition_two['sense_four'][repitition_two['sense_four'] < 4.52 ]= 4.52
    
    repitition_two['sense_five'][repitition_two['sense_five'] < 69.3] = 69.3
    repitition_two['sense_five'][repitition_two['sense_five'] > 72] = 72
    
    repitition_two['sense_six'][repitition_two['sense_six'] < 42] = 42
    
    repitition_two['sense_seven'][repitition_two['sense_seven'] < 52.5]= 52.5
    
    repitition_two['sense_eight'][repitition_two['sense_eight'] <4.3] = 4.3
    
    return

complete_2()

# %%
import matplotlib.pyplot as plt

for key in repitition_two.keys():
    plt.boxplot(repitition_two[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ '_no_outliers_repitition2_board_one_CO_at_80ppm.jpeg')

# %%
import matplotlib.pyplot as plt

for key in repitition_three.keys():
    plt.boxplot(repitition_three[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ 'board_onerepiition3_CO_at_80ppm.jpeg')

# %%
def complete_3():
    repitition_three['sense_one'][repitition_three['sense_one'] < 43.7] = 43.7
    repitition_three['sense_one'][repitition_three['sense_one'] > 45.0] = 45.0
    
    repitition_three['sense_two'][repitition_three['sense_two'] < 21.5] = 21.5
    
    repitition_three['sense_three'][repitition_three['sense_three'] < 24.3] = 24.3
    
    repitition_three['sense_four'][repitition_three['sense_four'] < 7.4 ]= 7.4
    
    repitition_three['sense_five'][repitition_three['sense_five'] < 79] = 79
    
    repitition_three['sense_six'][repitition_three['sense_six'] < 48.4] = 48.4
    
    repitition_three['sense_seven'][repitition_three['sense_seven'] < 64]= 64
    
    repitition_three['sense_eight'][repitition_three['sense_eight'] <7.2] = 7.2
    
    return

complete_3()

# %%
import matplotlib.pyplot as plt

for key in repitition_three.keys():
    plt.boxplot(repitition_three[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ 'board_one_no_outliers_repiition4_CO_at_80ppm.jpeg')

# %%
import matplotlib.pyplot as plt

for key in repitition_four.keys():
    plt.boxplot(repitition_four[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ 'board_onerepiition4_CO_at_90ppm.jpeg')

# %%
def complete_4():
    repitition_four['sense_one'][repitition_four['sense_one'] < 46.2] = 46.2
    repitition_four['sense_one'][repitition_four['sense_one'] > 47.1] = 47.1
    
    repitition_four['sense_two'][repitition_four['sense_two'] < 22.85] = 22.85
    
    repitition_four['sense_three'][repitition_four['sense_three'] < 25.80] = 25.80
    
    repitition_four['sense_four'][repitition_four['sense_four'] < 5.7 ]= 5.7
    
    repitition_four['sense_five'][repitition_four['sense_five'] < 85] = 85
    repitition_four['sense_five'][repitition_four['sense_five'] > 86.5] = 86.5
    
    repitition_four['sense_six'][repitition_four['sense_six'] < 50] = 50
    
    repitition_four['sense_seven'][repitition_four['sense_seven'] < 67.8]= 67.8
    
    repitition_four['sense_eight'][repitition_four['sense_eight'] <4.9] = 4.9
    
    return

complete_4()

# %%
import matplotlib.pyplot as plt

for key in repitition_four.keys():
    plt.boxplot(repitition_four[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ 'board_one_no_outliers_repiition4_CO_at_80ppm.jpeg')

# %%
final_repitition = (repitition_one + repitition_two+repitition_three + repitition_four) / 4

# %%
final_repitition.head()
# Out:
#    time  sense_one  sense_two  sense_three  sense_four  sense_five  sense_six  \
# 0  0.00     41.975    20.4175      23.4025      6.9150     78.1475    47.5175
# 1  0.01     41.995    20.3925      23.4125      6.9125     78.2050    47.5225
# 2  0.02     41.995    20.4075      23.4125      6.9175     78.0725    47.5150
# 3  0.03     41.995    20.3750      23.4025      6.9100     78.1475    47.5450
# 4  0.04     41.995    20.4000      23.4025      6.9125     78.0800    47.5225
#
#    sense_seven  sense_eight
# 0      61.5450       7.7525
# 1      61.5300       7.7625
# 2      61.5775       7.7575
# 3      61.5300       7.7575
# 4      61.5475       7.7575

# %%
final_repitition.to_csv('Repitition_CO_at_80_ppm.csv')
