# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'B1_GEy_F040_R1.txt',
#  'B1_GEy_F040_R2.txt',
#  'B1_GEy_F040_R3.txt',
#  'B1_GEy_F040_R4.txt',
#  'Merge_EY_40.ipynb']

# %%
import pandas as pd
repitition_one = pd.read_csv(r'B1_GEy_F040_R1.txt',sep = '\t',header = None)
repitition_one.columns = ['time','sense_one', 'sense_two', 'sense_three','sense_four','sense_five',
                          'sense_six','sense_seven','sense_eight']
repitition_two = pd.read_csv(r'B1_GEy_F040_R2.txt',sep = '\t',header = None)
repitition_two.columns = ['time','sense_one', 'sense_two', 'sense_three','sense_four','sense_five',
                          'sense_six','sense_seven','sense_eight']
repitition_three = pd.read_csv(r'B1_GEy_F040_R3.txt',sep = '\t',header = None)
repitition_three.columns = ['time','sense_one', 'sense_two', 'sense_three','sense_four','sense_five',
                          'sense_six','sense_seven','sense_eight']
repitition_four = pd.read_csv(r'B1_GEy_F040_R4.txt',sep = '\t',header = None)
repitition_four.columns = ['time','sense_one', 'sense_two', 'sense_three','sense_four','sense_five',
                          'sense_six','sense_seven','sense_eight']
repitition_four.head()
# Out:
#    time  sense_one  sense_two  sense_three  sense_four  sense_five  sense_six  \
# 0  0.00      40.42      19.85        22.83        8.08       74.43      43.02
# 1  0.01      40.42      19.85        22.83        8.09       74.43      43.02
# 2  0.02      40.42      19.85        22.83        8.08       74.66      43.11
# 3  0.03      40.42      19.85        22.83        8.08       74.66      43.02
# 4  0.04      40.42      19.82        22.83        8.08       74.66      43.11
#
#    sense_seven  sense_eight
# 0        60.59         8.27
# 1        60.91         8.27
# 2        60.59         8.28
# 3        60.75         8.27
# 4        60.91         8.28

# %%
import matplotlib.pyplot as plt

for key in repitition_one.keys():
    plt.boxplot(repitition_one[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ 'board_one_Ey_at_40ppm.jpeg')

# %%
def complete():
    repitition_one['sense_one'][repitition_one['sense_one'] < 42.2] = 42.2
    
    repitition_one['sense_two'][repitition_one['sense_two'] < 20.1] = 20.1
    
    repitition_one['sense_three'][repitition_one['sense_three'] < 23.1] = 23.1
    
    repitition_one['sense_four'][repitition_one['sense_four'] < 4.3]= 4.3
    
    repitition_one['sense_five'][repitition_one['sense_five'] < 77] = 77
    
    repitition_one['sense_six'][repitition_one['sense_six'] < 48.2] = 48.2
    
    repitition_one['sense_seven'][repitition_one['sense_seven'] < 58]= 58
    
    repitition_one['sense_eight'][repitition_one['sense_eight'] < 4.4]= 4.4
        
    return

complete()

# %%
import matplotlib.pyplot as plt

for key in repitition_one.keys():
    plt.boxplot(repitition_one[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ '_no_outliers_board_one_Ey_at_40ppm.jpeg')

# %%
import matplotlib.pyplot as plt

for key in repitition_two.keys():
    plt.boxplot(repitition_two[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ 'board_onerepiition2_EA_at_40ppm.jpeg')

# %%
def complete_2():
    repitition_two['sense_one'][repitition_two['sense_one'] < 32.4] = 32.4
        
    repitition_two['sense_two'][repitition_two['sense_two'] < 15.4] = 15.4
    
    repitition_two['sense_three'][repitition_two['sense_three'] < 17.8] = 17.8
    
    repitition_two['sense_four'][repitition_two['sense_four'] < 4.1] = 4.1
        
    repitition_two['sense_five'][repitition_two['sense_five'] < 61] = 61
    
    repitition_two['sense_six'][repitition_two['sense_six'] < 37.8] = 37.8
    
    repitition_two['sense_seven'][repitition_two['sense_seven'] < 47]= 47  
    
    repitition_two['sense_eight'][repitition_two['sense_eight'] < 4.3]= 4.3
    return

complete_2()

# %%
import matplotlib.pyplot as plt

for key in repitition_two.keys():
    plt.boxplot(repitition_two[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ '_no_outliers_repitition2_board_one_Ey_at_40ppm.jpeg')

# %%
import matplotlib.pyplot as plt

for key in repitition_three.keys():
    plt.boxplot(repitition_three[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ 'board_onerepition3_Ey_at_40ppm.jpeg')

# %%
def complete_3():
    repitition_three['sense_one'][repitition_three['sense_one'] < 41.6] = 41.6
    
    repitition_three['sense_two'][repitition_three['sense_two'] < 20.6] = 20.6
    
    repitition_three['sense_three'][repitition_three['sense_three'] < 23.1] = 23.1
    
    repitition_three['sense_four'][repitition_three['sense_four'] < 5.2] = 5.2
        
    repitition_three['sense_five'][repitition_three['sense_five'] < 74] = 74
    
    repitition_three['sense_six'][repitition_three['sense_six'] < 45.3] = 45.3
        
    repitition_three['sense_seven'][repitition_three['sense_seven'] < 60]= 60
    
    repitition_three['sense_eight'][repitition_three['sense_eight'] < 4.9] = 4.9
    return

complete_3()

# %%
import matplotlib.pyplot as plt

for key in repitition_three.keys():
    plt.boxplot(repitition_three[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ 'board_one_no_outliers_repiition3_Ey_at_40ppm.jpeg')

# %%
import matplotlib.pyplot as plt

for key in repitition_four.keys():
    plt.boxplot(repitition_four[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ 'board_onerepiition4_Ey_at_40ppm.jpeg')

# %%
def complete_4():
    repitition_four['sense_one'][repitition_four['sense_one'] < 39.9] = 39.9
    repitition_four['sense_one'][repitition_four['sense_one'] > 40.8] = 40.8
        
    repitition_four['sense_two'][repitition_four['sense_two'] < 19.8] = 19.8
    
    repitition_four['sense_three'][repitition_four['sense_three'] < 22.2] = 22.2

    repitition_four['sense_four'][repitition_four['sense_four'] < 5.7] = 5.7

    repitition_four['sense_five'][repitition_four['sense_five'] < 73] = 73
    
    repitition_four['sense_six'][repitition_four['sense_six'] < 42.2] = 42.2
        
    repitition_four['sense_seven'][repitition_four['sense_seven'] < 58]= 58
    
    repitition_four['sense_eight'][repitition_four['sense_eight'] < 5]= 5
    return

complete_4()

# %%
import matplotlib.pyplot as plt

for key in repitition_four.keys():
    plt.boxplot(repitition_four[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ 'board_one_no_outliers_repiition4_Ey_at_40ppm.jpeg')

# %%
final_repitition = (repitition_one + repitition_two+repitition_three + repitition_four) / 4

# %%
final_repitition.to_csv('Repitition_Ey_at_40_ppm.csv')
