# %%
import pandas as pd
repitition_one = pd.read_csv(r'B1_GME_F080_R1.txt',sep = '\t',header = None)
repitition_one.columns = ['time','sense_one', 'sense_two', 'sense_three','sense_four','sense_five',
                          'sense_six','sense_seven','sense_eight']
repitition_two = pd.read_csv(r'B1_GME_F080_R2.txt',sep = '\t',header = None)
repitition_two.columns = ['time','sense_one', 'sense_two', 'sense_three','sense_four','sense_five',
                          'sense_six','sense_seven','sense_eight']
repitition_three = pd.read_csv(r'B1_GME_F080_R3.txt',sep = '\t',header = None)
repitition_three.columns = ['time','sense_one', 'sense_two', 'sense_three','sense_four','sense_five',
                          'sense_six','sense_seven','sense_eight']
repitition_four = pd.read_csv(r'B1_GME_F080_R4.txt',sep = '\t',header = None)
repitition_four.columns = ['time','sense_one', 'sense_two', 'sense_three','sense_four','sense_five',
                          'sense_six','sense_seven','sense_eight']
repitition_four.head()
# Out:
#    time  sense_one  sense_two  sense_three  sense_four  sense_five  sense_six  \
# 0  0.00      40.18      20.22        22.73        8.13       73.75       44.5
# 1  0.01      40.18      20.22        22.73        8.12       73.52       44.6
# 2  0.02      40.18      20.19        22.70        8.12       73.75       44.6
# 3  0.03      40.10      20.19        22.70        8.12       73.52       44.5
# 4  0.04      40.10      20.22        22.70        8.12       73.75       44.5
#
#    sense_seven  sense_eight
# 0        59.95         8.18
# 1        59.80         8.20
# 2        59.80         8.20
# 3        59.80         8.18
# 4        59.80         8.18

# %%
import matplotlib.pyplot as plt

for key in repitition_one.keys():
    plt.boxplot(repitition_one[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ 'board_one_ME_at_80ppm.jpeg')

# %%
def complete():
    repitition_one['sense_one'][repitition_one['sense_one'] < 35.1] = 35.1
    
    repitition_one['sense_two'][repitition_one['sense_two'] < 17.9] = 17.9
    
    repitition_one['sense_three'][repitition_one['sense_three'] < 19.9] = 19.9
    
    repitition_one['sense_four'][repitition_one['sense_four'] < 5.0]= 5.0
    
    repitition_one['sense_five'][repitition_one['sense_five'] < 57] = 57
    
    repitition_one['sense_six'][repitition_one['sense_six'] < 36] = 36
    
    repitition_one['sense_seven'][repitition_one['sense_seven'] < 41]= 41
    
    repitition_one['sense_eight'][repitition_one['sense_eight'] <5.70] = 5.70
    
    return

complete()

# %%
import matplotlib.pyplot as plt

for key in repitition_one.keys():
    plt.boxplot(repitition_one[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ '_no_outliers_board_one_ME_at_80ppm.jpeg')

# %%
import matplotlib.pyplot as plt

for key in repitition_two.keys():
    plt.boxplot(repitition_two[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ 'board_onerepiition2_ME_at_70ppm.jpeg')

# %%
def complete_2():
    repitition_two['sense_one'][repitition_two['sense_one'] < 34.5] = 34.5
    
    repitition_two['sense_two'][repitition_two['sense_two'] < 16] = 16
    
    repitition_two['sense_three'][repitition_two['sense_three'] < 18] = 18
    
    repitition_two['sense_four'][repitition_two['sense_four'] < 5.40]= 5.40
    
    repitition_two['sense_five'][repitition_two['sense_five'] < 53] = 53
    
    repitition_two['sense_six'][repitition_two['sense_six'] < 34] = 34
    
    repitition_two['sense_seven'][repitition_two['sense_seven'] < 40]= 40
    
    repitition_two['sense_eight'][repitition_two['sense_eight'] <6.00] = 6.00
    
    return

complete_2()

# %%
import matplotlib.pyplot as plt

for key in repitition_two.keys():
    plt.boxplot(repitition_two[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ '_no_outliers_repitition2_board_one_ME_at_80ppm.jpeg')

# %%
import matplotlib.pyplot as plt

for key in repitition_three.keys():
    plt.boxplot(repitition_three[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ 'board_onerepition3_ME_at_80ppm.jpeg')

# %%
def complete_3():
    repitition_three['sense_one'][repitition_three['sense_one'] < 38] = 38
    
    repitition_three['sense_two'][repitition_three['sense_two'] < 19] = 19
    
    repitition_three['sense_three'][repitition_three['sense_three'] < 20.5] = 20.5
    
    repitition_three['sense_four'][repitition_three['sense_four'] < 6.50 ]= 6.50
    
    repitition_three['sense_five'][repitition_three['sense_five'] < 55] = 55
    
    repitition_three['sense_six'][repitition_three['sense_six'] < 34] = 34
    
    repitition_three['sense_seven'][repitition_three['sense_seven'] < 44.8]= 44.8
    
    repitition_three['sense_eight'][repitition_three['sense_eight'] <6.5] = 6.5
    
    return

complete_3()

# %%
import matplotlib.pyplot as plt

for key in repitition_three.keys():
    plt.boxplot(repitition_three[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ 'board_one_no_outliers_repiition3_ME_at_80ppm.jpeg')

# %%
import matplotlib.pyplot as plt

for key in repitition_four.keys():
    plt.boxplot(repitition_four[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ 'board_onerepiition4_ME_at_80ppm.jpeg')

# %%
def complete_4():
    repitition_four['sense_one'][repitition_four['sense_one'] < 35] = 35
    
    repitition_four['sense_two'][repitition_four['sense_two'] < 18.7] = 18.7
    
    repitition_four['sense_three'][repitition_four['sense_three'] < 19.7] = 19.7
    
    repitition_four['sense_four'][repitition_four['sense_four'] < 7.45 ]= 7.45
    
    repitition_four['sense_five'][repitition_four['sense_five'] < 51] = 51
    
    repitition_four['sense_six'][repitition_four['sense_six'] < 34] = 34
    
    repitition_four['sense_seven'][repitition_four['sense_seven'] < 41]= 41
    
    repitition_four['sense_eight'][repitition_four['sense_eight'] <7.30] = 7.30
    
    return

complete_4()

# %%
import matplotlib.pyplot as plt

for key in repitition_four.keys():
    plt.boxplot(repitition_four[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ 'board_one_no_outliers_repiition4_ME_at_80ppm.jpeg')

# %%
final_repitition = (repitition_one + repitition_two+repitition_three + repitition_four) / 4

# %%
final_repitition.to_csv('Repitition_ME_at_80_ppm.csv')
