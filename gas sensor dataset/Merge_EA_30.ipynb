# %%
import pandas as pd
repitition_one = pd.read_csv(r'B1_GEa_F030_R1.txt',sep = '\t',header = None)
repitition_one.columns = ['time','sense_one', 'sense_two', 'sense_three','sense_four','sense_five',
                          'sense_six','sense_seven','sense_eight']
repitition_two = pd.read_csv(r'B1_GEa_F030_R2.txt',sep = '\t',header = None)
repitition_two.columns = ['time','sense_one', 'sense_two', 'sense_three','sense_four','sense_five',
                          'sense_six','sense_seven','sense_eight']
repitition_three = pd.read_csv(r'B1_GEa_F030_R3.txt',sep = '\t',header = None)
repitition_three.columns = ['time','sense_one', 'sense_two', 'sense_three','sense_four','sense_five',
                          'sense_six','sense_seven','sense_eight']
repitition_four = pd.read_csv(r'B1_GEa_F030_R4.txt',sep = '\t',header = None)
repitition_four.columns = ['time','sense_one', 'sense_two', 'sense_three','sense_four','sense_five',
                          'sense_six','sense_seven','sense_eight']
repitition_four.head()
# Out:
#    time  sense_one  sense_two  sense_three  sense_four  sense_five  sense_six  \
# 0  0.00       50.9      24.40        28.39        7.42       92.88      52.49
# 1  0.01       50.9      24.40        28.39        7.43       92.88      52.49
# 2  0.02       50.9      24.44        28.39        7.42       93.22      52.49
# 3  0.03       50.9      24.40        28.39        7.43       92.88      52.49
# 4  0.04       50.9      24.40        28.39        7.42       92.88      52.49
#
#    sense_seven  sense_eight
# 0        73.68         7.47
# 1        73.68         7.47
# 2        73.68         7.48
# 3        73.68         7.47
# 4        73.68         7.47

# %%
import matplotlib.pyplot as plt

for key in repitition_one.keys():
    plt.boxplot(repitition_one[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ 'board_one_EA_at_30ppm.jpeg')

# %%
def complete():
    repitition_one['sense_one'][repitition_one['sense_one'] < 39.7] = 39.7
    
    repitition_one['sense_two'][repitition_one['sense_two'] > 19.98] = 19.98
    
    repitition_one['sense_three'][repitition_one['sense_three'] < 22] = 22
    
    repitition_one['sense_four'][repitition_one['sense_four'] < 1.7]= 1.7
    
    repitition_one['sense_five'][repitition_one['sense_five'] < 74.8] = 74.8
    
    repitition_one['sense_six'][repitition_one['sense_six'] > 48.7] = 48.7
    
    repitition_one['sense_seven'][repitition_one['sense_seven'] < 56]= 56
        
    return

complete()

# %%
import matplotlib.pyplot as plt

for key in repitition_one.keys():
    plt.boxplot(repitition_one[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ '_no_outliers_board_one_EA_at_30ppm.jpeg')

# %%
import matplotlib.pyplot as plt

for key in repitition_two.keys():
    plt.boxplot(repitition_two[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ 'board_onerepiition2_EA_at_30ppm.jpeg')

# %%
def complete_2():
    repitition_two['sense_one'][repitition_two['sense_one'] < 38.2] = 38.2
        
    repitition_two['sense_two'][repitition_two['sense_two'] < 18.18] = 18.18
    
    repitition_two['sense_three'][repitition_two['sense_three'] < 20.9] = 20.9
        
    repitition_two['sense_five'][repitition_two['sense_five'] < 72.5] = 72.5
    repitition_two['sense_five'][repitition_two['sense_five'] > 76.7] = 76.7
        
    repitition_two['sense_seven'][repitition_two['sense_seven'] < 54.9]= 54.9    
    return

complete_2()

# %%
import matplotlib.pyplot as plt

for key in repitition_two.keys():
    plt.boxplot(repitition_two[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ '_no_outliers_repitition2_board_one_EA_at_30ppm.jpeg')

# %%
import matplotlib.pyplot as plt

for key in repitition_three.keys():
    plt.boxplot(repitition_three[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ 'board_onerepition3_EA_at_30ppm.jpeg')

# %%
def complete_3():
    repitition_three['sense_one'][repitition_three['sense_one'] < 43.2] = 43.2
    repitition_three['sense_one'][repitition_three['sense_one'] > 44.2] = 44.2
    
    repitition_three['sense_two'][repitition_three['sense_two'] < 21.2] = 21.2
    
    repitition_three['sense_three'][repitition_three['sense_three'] < 24.2] = 24.2
        
    repitition_three['sense_five'][repitition_three['sense_five'] < 78.5] = 78.5
    
    repitition_three['sense_six'][repitition_three['sense_six'] > 48.5] = 48.5
        
    repitition_three['sense_seven'][repitition_three['sense_seven'] < 63]= 63    
    return

complete_3()

# %%
import matplotlib.pyplot as plt

for key in repitition_three.keys():
    plt.boxplot(repitition_three[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ 'board_one_no_outliers_repiition3_EA_at_30ppm.jpeg')

# %%
import matplotlib.pyplot as plt

for key in repitition_four.keys():
    plt.boxplot(repitition_four[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ 'board_onerepiition4_EA_at_30ppm.jpeg')

# %%
def complete_4():
    repitition_four['sense_one'][repitition_four['sense_one'] < 49.7] = 49.7
    repitition_four['sense_one'][repitition_four['sense_one'] > 50.9] = 50.9
    
    repitition_four['sense_two'][repitition_four['sense_two'] > 24.6] = 24.6
    
    repitition_four['sense_three'][repitition_four['sense_three'] < 27.7] = 27.7
    repitition_four['sense_three'][repitition_four['sense_three'] > 27.4] = 27.4
        
    repitition_four['sense_five'][repitition_four['sense_five'] < 89.8] = 89.8
    
    repitition_four['sense_six'][repitition_four['sense_six'] > 53.5] = 53.5
    
    repitition_four['sense_seven'][repitition_four['sense_seven'] < 70.5]= 70.5    
    return

complete_4()

# %%
import matplotlib.pyplot as plt

for key in repitition_four.keys():
    plt.boxplot(repitition_four[key])
    plt.grid('on')
    plt.title('Box plot of '+str(key))
    plt.show()
    plt.savefig('Box_plot_of_'+ str(key)+ 'board_one_no_outliers_repiition4_EA_at_30ppm.jpeg')

# %%
final_repitition = (repitition_one + repitition_two+repitition_three + repitition_four) / 4

# %%
final_repitition.to_csv('Repitition_EA_at_30_ppm.csv')
